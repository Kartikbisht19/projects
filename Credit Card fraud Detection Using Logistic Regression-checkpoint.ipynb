# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('C:\\Users\\DELL\\Desktop\\Credit Card Fraud Detection\\Dataset\\creditcard.csv')

# %%
dataset.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
dataset.shape
# Out:
# (284807, 31)

# %%
dataset.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
dataset.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
dataset.Class.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# Imbalanced Dataset

# %%
dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# # Imbalanced data

# %%
x = dataset.drop('Class',axis = 1)
y = dataset['Class']

# %%
x.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V20       V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...  0.251412 -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ... -0.069083 -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...  0.524980  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ... -0.208038 -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...  0.408542 -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1  0.167170  0.125895 -0.008983  0.014724    2.69
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3  0.647376 -0.221929  0.062723  0.061458  123.50
# 4 -0.206010  0.502292  0.219422  0.215153   69.99
#
# [5 rows x 30 columns]

# %%
y.sample(10)
# Out:
# 247008    0
# 204112    0
# 77938     0
# 50193     0
# 133919    0
# 45479     0
# 80497     0
# 159486    0
# 201680    0
# 271707    0
# Name: Class, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2, random_state = 2)

# %%
x_train.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 136700   81827.0 -0.626902  1.172790  1.750623  0.868050  0.015424 -0.771009
# 43219    41420.0 -0.006068 -2.885932 -0.764538  0.091419 -1.687394 -0.859819
# 18819    29792.0 -0.531514  0.611990  1.677510  1.281703  0.468128  0.025695
# 174557  121967.0  1.789550 -0.556617 -1.534874  0.343963  0.202157  0.118209
# 120641   75904.0  1.254183 -0.106286 -0.882852  0.308304  1.985428  3.808663
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 136700  1.017371 -0.533478 -0.424700  ...  0.017828  0.070241  0.369148
# 43219   0.624534 -0.416351 -0.654780  ...  1.473102  0.584560 -0.003808
# 18819   0.900121 -0.306788  0.252843  ...  0.170019 -0.145452  0.238458
# 174557 -0.227615 -0.003945  0.972636  ...  0.222229 -0.307981 -1.132447
# 120641 -0.684194  0.938692  0.416300  ... -0.048902 -0.137631 -0.289971
#
#              V23       V24       V25       V26       V27       V28  Amount
# 136700 -0.063796  0.734099 -0.301282 -0.502040 -0.375145 -0.081215   19.99
# 43219  -0.801507  0.453660  0.474506 -0.140280 -0.157441  0.130219  751.12
# 18819  -0.073162  0.066287 -0.156348 -0.283686 -0.021930 -0.245350   20.67
# 174557  0.184282 -0.424180 -0.503949  0.134031 -0.049449  0.006778  157.51
# 120641 -0.132417  1.018395  0.862443 -0.282622  0.043088  0.015524    2.30
#
# [5 rows x 30 columns]

# %%
y_train.head()
# Out:
# 136700    0
# 43219     0
# 18819     0
# 174557    0
# 120641    0
# Name: Class, dtype: int64

# %%
x_test.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 225184  144140.0 -0.581460  0.950267  0.115938 -1.384767  1.388364 -1.595678
# 116637   74369.0  0.686730 -0.785586  0.945092  1.476634 -1.191074 -0.193185
# 99414    67107.0 -0.848395  1.214313  0.954869 -0.030145 -0.177527 -0.851855
# 217619  140965.0 -1.104465  0.616952 -0.878973 -0.312839 -0.092112 -0.020623
# 279878  169155.0  2.061985 -0.114758 -1.079406  0.427062 -0.229701 -1.241109
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 225184  2.120867 -0.718954 -0.205211  ... -0.292792  0.153480  0.656548
# 116637 -0.217963 -0.011827  0.727172  ...  0.388521  0.277960  0.419683
# 99414   0.444232  0.369063 -1.005181  ...  0.079630  0.205928  0.552455
# 217619  1.422463  0.442278 -0.406603  ...  0.511897  0.265005  0.438796
# 279878  0.121975 -0.283331  0.679923  ... -0.284520 -0.299538 -0.772333
#
#              V23       V24       V25       V26       V27       V28  Amount
# 225184 -0.514192  0.077220  0.736220 -0.302469 -0.254862 -0.126279   12.82
# 116637 -0.314303  0.427369  0.426733 -0.285560  0.022906  0.079838  256.39
# 99414  -0.064845  0.590082 -0.271787  0.276440  0.217840  0.127724   16.44
# 217619  0.413781  0.649776 -0.082746  0.520578  0.151103  0.216899  270.00
# 279878  0.352777  0.021161 -0.330437  0.198512 -0.076625 -0.061905    1.29
#
# [5 rows x 30 columns]

# %%
y_test.head()
# Out:
# 225184    0
# 116637    0
# 99414     0
# 217619    0
# 279878    0
# Name: Class, dtype: int64

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (284807, 30) (227845, 30) (56962, 30)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score

x_train_prediction = model.predict(x_train)
training_accuracy = accuracy_score(x_train_prediction, y_train)

# %%
training_accuracy
# Out:
# 0.9988676512541421

# %%
x_test_prediction = model.predict(x_test)
test_accuracy = accuracy_score(x_test_prediction, y_test)

# %%
test_accuracy
# Out:
# 0.9988764439450862

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, x_test_prediction))
# Out:
# [[56835    43]
#  [   21    63]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, x_test_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56878
#            1       0.59      0.75      0.66        84
#
#     accuracy                           1.00     56962
#    macro avg       0.80      0.87      0.83     56962
# weighted avg       1.00      1.00      1.00     56962

# %% [markdown]
# # Balance data

# %%
legit = dataset[dataset['Class'] == 0]
legit.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
fraud = dataset[dataset['Class'] == 1]
fraud.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 541    406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108  6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329  7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920  0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
# 6108 -3.496197 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207
# 6329  1.713445 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805
#
#            V24       V25       V26       V27       V28  Amount  Class
# 541   0.320198  0.044519  0.177840  0.261145 -0.143276    0.00      1
# 623  -0.293803  0.279798 -0.145362 -0.252773  0.035764  529.00      1
# 4920 -0.087330 -0.156114 -0.542628  0.039566 -0.153029  239.93      1
# 6108 -0.053502  0.252405 -0.657488 -0.827136  0.849573   59.00      1
# 6329 -1.632653  1.488901  0.566797 -0.010016  0.146793    1.00      1
#
# [5 rows x 31 columns]

# %%
print(legit.shape)
# Out:
# (284315, 31)

# %%
print(fraud.shape)
# Out:
# (492, 31)

# %%
legit.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  284315.000000  284315.000000  284315.000000  284315.000000
# mean    94838.202258       0.008258      -0.006271       0.012171
# std     47484.015786       1.929814       1.636146       1.459429
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54230.000000      -0.917544      -0.599473      -0.884541
# 50%     84711.000000       0.020023       0.064070       0.182158
# 75%    139333.000000       1.316218       0.800446       1.028372
# max    172792.000000       2.454930      18.902453       9.382558
#
#                   V4             V5             V6             V7  \
# count  284315.000000  284315.000000  284315.000000  284315.000000
# mean       -0.007860       0.005453       0.002419       0.009637
# std         1.399333       1.356952       1.329913       1.178812
# min        -5.683171    -113.743307     -26.160506     -31.764946
# 25%        -0.850077      -0.689398      -0.766847      -0.551442
# 50%        -0.022405      -0.053457      -0.273123       0.041138
# 75%         0.737624       0.612181       0.399619       0.571019
# max        16.875344      34.801666      73.301626     120.589494
#
#                   V8             V9  ...            V21            V22  \
# count  284315.000000  284315.000000  ...  284315.000000  284315.000000
# mean       -0.000987       0.004467  ...      -0.001235      -0.000024
# std         1.161283       1.089372  ...       0.716743       0.723668
# min       -73.216718      -6.290730  ...     -34.830382     -10.933144
# 25%        -0.208633      -0.640412  ...      -0.228509      -0.542403
# 50%         0.022041      -0.049964  ...      -0.029821       0.006736
# 75%         0.326200       0.598230  ...       0.185626       0.528407
# max        18.709255      15.594995  ...      22.614889      10.503090
#
#                  V23            V24            V25            V26  \
# count  284315.000000  284315.000000  284315.000000  284315.000000
# mean        0.000070       0.000182      -0.000072      -0.000089
# std         0.621541       0.605776       0.520673       0.482241
# min       -44.807735      -2.836627     -10.295397      -2.604551
# 25%        -0.161702      -0.354425      -0.317145      -0.327074
# 50%        -0.011147       0.041082       0.016417      -0.052227
# 75%         0.147522       0.439869       0.350594       0.240671
# max        22.528412       4.584549       7.519589       3.517346
#
#                  V27            V28         Amount     Class
# count  284315.000000  284315.000000  284315.000000  284315.0
# mean       -0.000295      -0.000131      88.291022       0.0
# std         0.399847       0.329570     250.105092       0.0
# min       -22.565679     -15.430084       0.000000       0.0
# 25%        -0.070852      -0.052950       5.650000       0.0
# 50%         0.001230       0.011199      22.000000       0.0
# 75%         0.090573       0.077962      77.050000       0.0
# max        31.612198      33.847808   25691.160000       0.0
#
# [8 rows x 31 columns]

# %%
fraud.describe()
# Out:
#                 Time          V1          V2          V3          V4  \
# count     492.000000  492.000000  492.000000  492.000000  492.000000
# mean    80746.806911   -4.771948    3.623778   -7.033281    4.542029
# std     47835.365138    6.783687    4.291216    7.110937    2.873318
# min       406.000000  -30.552380   -8.402154  -31.103685   -1.313275
# 25%     41241.500000   -6.036063    1.188226   -8.643489    2.373050
# 50%     75568.500000   -2.342497    2.717869   -5.075257    4.177147
# 75%    128483.000000   -0.419200    4.971257   -2.276185    6.348729
# max    170348.000000    2.132386   22.057729    2.250210   12.114672
#
#                V5          V6          V7          V8          V9  ...  \
# count  492.000000  492.000000  492.000000  492.000000  492.000000  ...
# mean    -3.151225   -1.397737   -5.568731    0.570636   -2.581123  ...
# std      5.372468    1.858124    7.206773    6.797831    2.500896  ...
# min    -22.105532   -6.406267  -43.557242  -41.044261  -13.434066  ...
# 25%     -4.792835   -2.501511   -7.965295   -0.195336   -3.872383  ...
# 50%     -1.522962   -1.424616   -3.034402    0.621508   -2.208768  ...
# 75%      0.214562   -0.413216   -0.945954    1.764879   -0.787850  ...
# max     11.095089    6.474115    5.802537   20.007208    3.353525  ...
#
#               V21         V22         V23         V24         V25         V26  \
# count  492.000000  492.000000  492.000000  492.000000  492.000000  492.000000
# mean     0.713588    0.014049   -0.040308   -0.105130    0.041449    0.051648
# std      3.869304    1.494602    1.579642    0.515577    0.797205    0.471679
# min    -22.797604   -8.887017  -19.254328   -2.028024   -4.781606   -1.152671
# 25%      0.041787   -0.533764   -0.342175   -0.436809   -0.314348   -0.259416
# 50%      0.592146    0.048434   -0.073135   -0.060795    0.088371    0.004321
# 75%      1.244611    0.617474    0.308378    0.285328    0.456515    0.396733
# max     27.202839    8.361985    5.466230    1.091435    2.208209    2.745261
#
#               V27         V28       Amount  Class
# count  492.000000  492.000000   492.000000  492.0
# mean     0.170575    0.075667   122.211321    1.0
# std      1.376766    0.547291   256.683288    0.0
# min     -7.263482   -1.869290     0.000000    1.0
# 25%     -0.020025   -0.108868     1.000000    1.0
# 50%      0.394926    0.146344     9.250000    1.0
# 75%      0.826029    0.381152   105.890000    1.0
# max      3.052358    1.779364  2125.870000    1.0
#
# [8 rows x 31 columns]

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
legit_sample = legit.sample(492)

# %%
df = legit_sample.append(fraud)

# %%
df.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 107640   70537.0 -0.551557  0.413908  2.090319  0.515552 -0.605709  0.292396
# 214051  139512.0 -1.405164 -1.647835 -0.016433 -3.323101  2.798202  3.274558
# 79859    58211.0 -4.582533  3.980154 -0.463068 -1.196031 -0.791080 -0.659116
# 28441    35013.0 -0.893009  0.870897  1.787541 -0.539964  0.339110 -1.186632
# 123481   76944.0  1.265816  0.726514 -0.368162  1.218526  0.285789 -0.970089
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 107640  0.221746  0.338916 -0.167596  ...  0.246342  0.449847  0.001557
# 214051 -0.562185  1.115607 -0.825759  ... -0.002120 -0.737678  0.481905
# 79859   0.487344  0.305398  2.995103  ... -0.847823 -0.909629  0.072467
# 28441   0.773348 -0.028636 -0.432279  ... -0.237143 -0.914341 -0.154564
# 123481  0.352509 -0.274257 -0.197763  ... -0.064907 -0.068669 -0.174808
#
#              V24       V25       V26       V27       V28  Amount  Class
# 107640 -0.071413 -0.127234 -0.396794  0.070723  0.070401   90.00      0
# 214051  0.632896 -0.020098 -0.727989  0.019071  0.141994  140.65      0
# 79859  -0.114144  0.612530  0.043727  1.092191  0.232851    8.97      0
# 28441   0.299486  0.223580 -0.025554 -0.027874  0.070980    1.98      0
# 123481 -0.057881  0.770841 -0.308394  0.037505  0.049607    1.00      0
#
# [5 rows x 31 columns]

# %%
df.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
#              V24       V25       V26       V27       V28  Amount  Class
# 279863 -0.294885  0.537503  0.788395  0.292680  0.147968  390.00      1
# 280143 -0.081049  0.521875  0.739467  0.389152  0.186637    0.76      1
# 280149  0.032070 -0.739695  0.471111  0.385107  0.194361   77.89      1
# 281144 -0.183659 -0.328168  0.606116  0.884876 -0.253700  245.00      1
# 281674 -0.450261  0.313267 -0.289617  0.002988 -0.015309   42.53      1
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (984, 31)

# %%
df.sample(10)
# Out:
#             Time         V1        V2         V3        V4         V5  \
# 44223    41851.0 -19.139733  9.286847 -20.134992  7.818673 -15.652208
# 41395    40662.0  -4.446847 -0.014793  -5.126307  6.945130   5.269255
# 139570   83222.0   1.179174  0.242981   0.417366  1.385300  -0.125591
# 41943    40892.0  -2.140511  4.104871  -8.996859  4.028391  -5.131359
# 150663   93853.0  -5.839192  7.151532 -12.816760  7.031115  -9.651272
# 212516  138894.0  -1.298443  1.948100  -4.509947  1.305805  -0.019486
# 217588  140950.0   2.027937 -0.145054  -1.655086  0.625525   0.101152
# 6774      8528.0   0.447396  2.481954  -5.660814  4.455923  -2.443780
# 75073    55886.0  -2.000911  1.898854   0.907005 -1.775231  -0.434380
# 75511    56098.0  -1.229669  1.956099  -0.851198  2.796987  -1.913977
#
#               V6         V7        V8        V9  ...       V21       V22  \
# 44223  -1.668348 -21.340478  0.641900 -8.550110  ... -2.182692  0.520543
# 41395  -4.297177  -2.591242  0.342671 -3.880663  ...  0.247913 -0.049586
# 139570 -0.178949   0.069121 -0.022218  0.267712  ... -0.104469 -0.039485
# 41943  -4.153568  -9.360095  1.922075 -4.026180  ...  1.854267 -0.165534
# 150663 -2.938427 -11.543207  4.843627 -3.494276  ...  2.462056  1.054865
# 212516 -0.509238  -2.643398  1.283545 -2.515356  ...  1.178032  1.360989
# 217588 -1.196140   0.378508 -0.289005  0.592225  ... -0.019655 -0.011529
# 6774   -2.185040  -4.716143  1.249803 -0.718326  ...  0.756053  0.140168
# 75073  -0.851945   0.578519 -0.033114  1.478251  ... -0.372966 -0.250327
# 75511  -0.044934  -1.340739 -0.555548 -1.184468  ...  1.208054  0.277612
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 44223  -0.760556  0.662767 -0.948454  0.121796 -3.381843 -1.256524  139.90
# 41395  -0.226017 -0.401236  0.856124  0.661272  0.492560  0.971834    1.00
# 139570 -0.057345  0.098835  0.671309 -0.312553  0.042313  0.015095    1.00
# 41943  -0.339939  0.296314  1.364225 -0.518996  2.352333  1.130625    0.76
# 150663  0.530481  0.472670 -0.275998  0.282435  0.104886  0.254417  316.06
# 212516 -0.272013 -0.325948  0.290703  0.841295  0.643094  0.201156    0.01
# 217588  0.155259  1.147484  0.119448  0.324920 -0.102899 -0.063871   23.74
# 6774    0.665411  0.131464 -1.908217  0.334808  0.748534  0.175414    1.00
# 75073  -0.015972  0.334401  0.012149  0.654591  0.287034 -0.253099    1.46
# 75511   0.019266  0.508529 -0.201183 -0.249600  0.562239  0.075309  170.92
#
#         Class
# 44223       1
# 41395       1
# 139570      0
# 41943       1
# 150663      1
# 212516      1
# 217588      0
# 6774        1
# 75073       0
# 75511       1
#
# [10 rows x 31 columns]

# %%
df['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      95546.565041  0.024462  0.046718  0.020417 -0.120193  0.020378
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.033994 -0.039613 -0.101804 -0.131532  ...  0.010384 -0.078838
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.034859  0.015130  0.016006  0.019598 -0.018713  0.000937 -0.023238
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       75.293963
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
x = df.drop('Class',axis = 1)
y = df['Class']

# %%
x.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 107640   70537.0 -0.551557  0.413908  2.090319  0.515552 -0.605709  0.292396
# 214051  139512.0 -1.405164 -1.647835 -0.016433 -3.323101  2.798202  3.274558
# 79859    58211.0 -4.582533  3.980154 -0.463068 -1.196031 -0.791080 -0.659116
# 28441    35013.0 -0.893009  0.870897  1.787541 -0.539964  0.339110 -1.186632
# 123481   76944.0  1.265816  0.726514 -0.368162  1.218526  0.285789 -0.970089
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 107640  0.221746  0.338916 -0.167596  ...  0.056427  0.246342  0.449847
# 214051 -0.562185  1.115607 -0.825759  ...  0.532599 -0.002120 -0.737678
# 79859   0.487344  0.305398  2.995103  ...  2.293989 -0.847823 -0.909629
# 28441   0.773348 -0.028636 -0.432279  ... -0.129239 -0.237143 -0.914341
# 123481  0.352509 -0.274257 -0.197763  ... -0.034338 -0.064907 -0.068669
#
#              V23       V24       V25       V26       V27       V28  Amount
# 107640  0.001557 -0.071413 -0.127234 -0.396794  0.070723  0.070401   90.00
# 214051  0.481905  0.632896 -0.020098 -0.727989  0.019071  0.141994  140.65
# 79859   0.072467 -0.114144  0.612530  0.043727  1.092191  0.232851    8.97
# 28441  -0.154564  0.299486  0.223580 -0.025554 -0.027874  0.070980    1.98
# 123481 -0.174808 -0.057881  0.770841 -0.308394  0.037505  0.049607    1.00
#
# [5 rows x 30 columns]

# %%
y.sample(10)
# Out:
# 263274    1
# 186757    0
# 92777     1
# 251904    1
# 8617      1
# 217507    0
# 42769     1
# 204079    1
# 31709     0
# 42756     1
# Name: Class, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2, random_state = 2)

# %%
x_train.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 42007    40918.0 -3.140260  3.367342 -2.778931  3.859701 -1.159518 -0.721552
# 103207   68546.0  1.306013  0.182200 -1.463537  0.058926  2.413263  3.218614
# 167124  118497.0  1.910538 -0.257031 -1.263320  0.289160  0.510262  0.363065
# 145675   87122.0  1.520067 -0.789331 -1.776289  0.598183 -0.054054 -0.467878
# 123679   77021.0  0.754280 -1.886735  1.152219  0.002235 -2.124449  0.063190
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 42007  -4.195342 -0.598346 -2.870145  ...  0.077781  2.452339 -0.292963
# 103207 -0.196005  0.717948 -0.330764  ... -0.025003 -0.083232 -0.353299
# 167124 -0.029114  0.111406  0.584640  ... -0.318814 -0.159998 -0.193803
# 145675  0.164583 -0.080883  0.435433  ...  0.344788  0.099043 -0.192270
# 123679 -1.001666  0.080124  0.458491  ...  0.638217  0.267447  0.400577
#
#              V23       V24       V25       V26       V27       V28  Amount
# 42007  -0.189330 -0.166482  0.038040 -0.015477  0.776691  0.397557    0.76
# 103207 -0.127709  0.998504  0.881116 -0.326947  0.004209  0.010244    4.99
# 167124  0.365424 -1.020164 -0.426967  0.373664 -0.021880 -0.073670   11.10
# 145675 -0.003671  0.691977 -0.296199  0.360987 -0.101200  0.009024  253.00
# 123679 -0.314563  0.470113  0.338819 -0.150144  0.019271  0.077867  300.00
#
# [5 rows x 30 columns]

# %%
y_train.head()
# Out:
# 42007     1
# 103207    0
# 167124    0
# 145675    0
# 123679    0
# Name: Class, dtype: int64

# %%
x_test.head()
# Out:
#             Time         V1        V2         V3         V4         V5  \
# 148897   90296.0  -1.107073 -3.298902  -0.184092  -1.795744   2.137564
# 11343    19762.0 -14.179165  7.421370 -21.405836  11.927512  -7.974281
# 150715   93965.0 -11.397727  7.763953 -18.572307   6.711855 -10.174216
# 197991  132268.0  -0.424681  1.428802  -0.181537   0.629908   2.352444
# 58761    48533.0   1.243848  0.524526  -0.538884   1.209196   0.479538
#
#               V6         V7        V8        V9  ...       V20       V21  \
# 148897 -1.684992  -2.015606 -0.007181 -0.165760  ...  0.348269  0.130648
# 11343  -2.202710 -15.471612 -0.356595 -6.380125  ...  1.002764 -2.366836
# 150715 -4.395918 -15.893788  2.083013 -4.988837  ...  0.208879  0.339007
# 197991  0.435719   1.629085 -0.249809 -1.295429  ...  0.269937 -0.078975
# 58761  -0.197429   0.049166  0.037792  0.128119  ... -0.171541 -0.051660
#
#              V22       V23       V24       V25       V26       V27       V28  \
# 148897  0.329445  0.927656 -0.049560 -1.892866 -0.575431  0.266573  0.414184
# 11343   1.130955  0.991153 -1.033132 -0.327179  0.634693  2.171905 -1.395288
# 150715  1.342923  0.239217  0.534644 -0.174965 -0.500240 -1.722060 -0.574339
# 197991  0.048994 -0.760739 -0.443335  1.241727 -0.203379 -0.110693 -0.150659
# 58761  -0.084089 -0.192846 -0.917392  0.681953 -0.194419  0.045917  0.040136
#
#         Amount
# 148897   62.10
# 11343     1.00
# 150715   11.40
# 197991   14.32
# 58761     1.00
#
# [5 rows x 30 columns]

# %%
y_test.head()
# Out:
# 148897    0
# 11343     1
# 150715    1
# 197991    0
# 58761     1
# Name: Class, dtype: int64

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score

x_train_prediction = model.predict(x_train)
training_accuracy = accuracy_score(x_train_prediction, y_train)

# %%
training_accuracy
# Out:
# 0.9186785260482846

# %%
x_test_prediction = model.predict(x_test)
test_accuracy = accuracy_score(x_test_prediction, y_test)

# %%
test_accuracy
# Out:
# 0.9187817258883249

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, x_test_prediction))
# Out:
# [[90  5]
#  [11 91]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, x_test_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92        95
#            1       0.95      0.89      0.92       102
#
#     accuracy                           0.92       197
#    macro avg       0.92      0.92      0.92       197
# weighted avg       0.92      0.92      0.92       197
